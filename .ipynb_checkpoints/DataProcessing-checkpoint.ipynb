# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
datadir = "/home/sywi/Documents/AirPolutionPrediction/Data/"
fulldir = os.path.join(os.getcwd(), datadir)
allfiles = os.listdir(fulldir)
allfiles.sort(key= lambda x: x.split('_')[0])

for filename in reversed(allfiles):
    name = 'Data/' + filename
    temp_df = pd.read_csv(name, sep=";", index_col='Date')
    temp_df.drop([temp_df.columns[1]],axis=1, inplace=True)
    
    try:
        print('hi')
        pd.concat([kras_df, temp_df], axis=0)
    except:
        kras_df = pd.DataFrame(temp_df)
        
    print(name)

kras_df.info()
# Out:
# hi
# Data/2018_PM10_Kras.csv
# hi
# Data/2017_PM10_Kras.csv
# hi
# Data/2016_PM10_Kras.csv
# hi
# Data/2015_PM10_Kras.csv
# hi
# Data/2013_PM10_Kras.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 8735 entries, 2018-01-01 01:00 to 2018-12-31 00:00
# Data columns (total 1 columns):
#  AlKras    8565 non-null float64
# dtypes: float64(1)
# memory usage: 136.5+ KB

# %%
Kras_df = pd.read_csv("Data/2018_PM10_Kras.csv", sep=";")
Kras_df.drop([Kras_df.columns[0], Kras_df.columns[2]],axis=1, inplace=True)
Kras_df.head()
# Out:
#     AlKras
# 0     26.3
# 1     59.1
# 2     35.9
# 3     39.6
# 4     39.6

# %%
Kras_df.info()   # they are not stored as nunmeric data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8735 entries, 0 to 8734
# Data columns (total 1 columns):
#  AlKras    8565 non-null float64
# dtypes: float64(1)
# memory usage: 68.3 KB

# %%
kras_arr = Kras_df.values
print('number of NA', Kras_df.isna().sum())
kras_arr[np.isnan(kras_arr)==True]
# Out:
# number of NA  AlKras    170
# dtype: int64
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# # Moving average vs normal data
# moving average also handles missing values

# %%
avg = Kras_df.rolling(24, min_periods=1).mean()
avg = round(avg, 3)
print('avg shape:', avg.shape)

fig = plt.figure(figsize=(16,4))

ax = fig.add_subplot(121)
ax.plot(avg)
ax.set_title('moving average')


ax = fig.add_subplot(122)
ax.plot(Kras_df)
ax.set_title('normal')
# Out:
# avg shape: (8735, 1)
# Text(0.5, 1.0, 'normal')

# %%
print('lenght = ',len(avg))
print('number of na = ', avg.isna().sum())
# Out:
# lenght =  8735
# number of na =   AlKras    91
# dtype: int64

# %% [markdown]
# # plotting few days

# %%
#inital values
n_days = 7
first_day = 40
period_h = 24

fig = plt.figure(figsize=(12,4))
plt.subplots_adjust(bottom=0.1, top=3, hspace = 0.5)
#plt.tight_layout(rect=(0, 0, 2, 2))

for i in range(n_days):
    ax = fig.add_subplot(n_days,2,2*i+1)
    ax.plot(avg[period_h*(i+first_day):period_h*(i+1+first_day)])
    ax.set_title('mavg day: ' + str(i+1+first_day))
    ax.set_ylim(bottom=avg.min(), top=avg.max())
    
    ax = fig.add_subplot(n_days,2,2*(i+1))
    ax.plot(best_stations_df['MpKrakAlKras'][period_h*(i+first_day):period_h*(i+1+first_day)])
    ax.set_title('normal day: ' + str(i+1+first_day))
    ax.set_ylim(bottom=best_stations_df['MpKrakAlKras'].min(), top=best_stations_df['MpKrakAlKras'].max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9f104542591b> in <module>
#      12     ax.plot(avg[period_h*(i+first_day):period_h*(i+1+first_day)])
#      13     ax.set_title('mavg day: ' + str(i+1+first_day))
# ---> 14     ax.set_ylim(bottom=avg.min(), top=avg.max())
#      15
#      16     ax = fig.add_subplot(n_days,2,2*(i+1))
#
# ~/Documents/vpd/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3624             top = old_top
#    3625
# -> 3626         if bottom == top:
#    3627             warnings.warn(
#    3628                 ('Attempting to set identical bottom==top results\n'
#
# ~/Documents/vpd/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
# ...

# %% [markdown]
# # Save data

# %%
avg.to_csv("Data/MpKrakAlKras.csv", header=True, index=False)
