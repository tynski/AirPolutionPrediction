# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("Data/2017_PM10_1g.xlsx") # load

# %%
df.head(29)                             # look
# Out:
#                      Nr                     1                     2  \
# 0            Kod stacji          DsBoleslaMOB          DsDzialoszyn
# 1              Wskaźnik                  PM10                  PM10
# 2      Czas uśredniania                    1g                    1g
# 3             Jednostka                 ug/m3                 ug/m3
# 4        Kod stanowiska  DsBoleslaMOB-PM10-1g  DsDzialoszyn-PM10-1g
# 5   2017-01-01 01:00:00                   NaN               53,3963
# 6   2017-01-01 02:00:00                   NaN               52,9082
# 7   2017-01-01 03:00:00                   NaN               51,3831
# 8   2017-01-01 04:00:00                   NaN               44,6262
# 9   2017-01-01 05:00:00                   NaN               41,5999
# 10  2017-01-01 06:00:00                   NaN               44,7345
# 11  2017-01-01 07:00:00                   NaN               41,9268
# 12  2017-01-01 08:00:00                   NaN               43,9248
# 13  2017-01-01 09:00:00                   NaN               45,1005
# 14  2017-01-01 10:00:00                   NaN               44,5592
# 15  2017-01-01 11:00:00                   NaN               50,3831
# 16  2017-01-01 12:00:00                   NaN               42,9543
# 17  2017-01-01 13:00:00                   NaN               53,1047
# 18  2017-01-01 14:00:00                   NaN               49,2967
# 19  2017-01-01 15:00:00                   NaN               44,6584
# 20  2017-01-01 16:00:00                   NaN               41,7439
# 21  2017-01-01 17:00:00                   NaN               43,6875
# 22  2017-01-01 18:00:00                   NaN               49,2292
# 23  2017-01-01 19:00:00                   NaN               50,7784
# 24  2017-01-01 20:00:00                   NaN               49,1495
# 25  2017-01-01 21:00:00                   NaN               48,5216
# 26  2017-01-01 22:00:00                   NaN               46,9135
# 27  2017-01-01 23:00:00                   NaN               47,6578
# 28  2017-01-02 00:00:00                   NaN               47,4247
#
#                        3                     4                     5  \
# 0           DsDziePilsud          DsJelGorOgin          DsKlodzSzkol
# 1                   PM10                  PM10                  PM10
# 2                     1g                    1g                    1g
# 3                  ug/m3                 ug/m3                 ug/m3
# 4   DsDziePilsud-PM10-1g  DsJelGorOgin-PM10-1g  DsKlodzSzkol-PM10-1g
# 5                  405,0               226,603               289,173
# 6                310,984               229,432                265,72
# 7                455,381               253,827               243,228
# 8                  290,6               225,692               258,756
# 9                263,553               254,761               242,493
# 10               170,725               205,914               232,529
# 11               133,309               179,852               222,997
# 12               111,125               199,966               217,821
# 13                179,91                213,83               190,327
# 14               162,899               211,623               157,315
# 15               123,721               161,697               122,256
# 16               54,8987               84,8149               92,8836
# 17               58,4377               38,7087                146,56
# 18               38,5926               42,8155               38,8257
# 19               16,9719               45,3499               37,2905
# 20               31,7655               51,7999               103,111
# 21               53,2885               62,9217               78,3203
# 22               89,3762               63,6299               176,121
# 23               137,429               127,292               271,204
# 24               138,396               127,131                255,56
# 25               132,434               150,656               244,337
# 26               38,2733               221,807               294,121
# 27               37,6207                274,94               302,072
# 28               37,6995               250,959               299,936
#
#                       6                     7                     8  \
# 0           DsKudowaMOB          DsLegAlRzecz          DsNowRudSreb
# 1                  PM10                  PM10                  PM10
# 2                    1g                    1g                    1g
# 3                 ug/m3                 ug/m3                 ug/m3
# 4   DsKudowaMOB-PM10-1g  DsLegAlRzecz-PM10-1g  DsNowRudSreb-PM10-1g
# 5                   NaN               80,1625               446,146
# 6                   NaN               38,6769               473,629
# 7                   NaN               47,0206               336,169
# 8                   NaN               31,2669               285,767
# 9                   NaN                53,598               270,204
# 10                  NaN               46,6094               261,451
# 11                  NaN               43,5636               220,985
# 12                  NaN               70,6806                255,02
# 13                  NaN                   NaN               292,576
# 14                  NaN                39,029               372,571
# 15                  NaN               30,9068               473,812
# 16                  NaN                30,688               426,222
# 17                  NaN               31,9582               159,509
# 18                  NaN               46,5257               43,8629
# 19                  NaN               49,9943               45,8648
# 20                  NaN               30,6166                 45,69
# 21                  NaN               33,9248                96,111
# 22                  NaN                  69,4               126,518
# 23                  NaN               102,711                258,06
# 24                  NaN                139,49               359,814
# 25                  NaN               135,874               378,505
# 26                  NaN               128,809               378,283
# 27                  NaN               145,841               324,147
# 28                  NaN               134,473               308,046
#
#                        9  ...                   114                   115  \
# 0           DsWalbrzWyso  ...          WpBoroDrapal          WpKaliSawick
# 1                   PM10  ...                  PM10                  PM10
# 2                     1g  ...                    1g                    1g
# 3                  ug/m3  ...                 ug/m3                 ug/m3
# 4   DsWalbrzWyso-PM10-1g  ...  WpBoroDrapal-PM10-1g  WpKaliSawick-PM10-1g
# 5                467,889  ...               23,4837               61,8409
# 6                144,374  ...               44,2607               117,002
# 7                61,1247  ...               40,7959               32,0493
# 8                65,8004  ...               19,5365               31,6062
# 9                59,9626  ...               23,4659               26,8417
# 10               48,2143  ...                22,321               33,1624
# 11               45,1754  ...               24,2267               27,0599
# 12               63,2311  ...               25,2725               26,5927
# 13               64,2735  ...                28,239               25,9831
# 14                96,395  ...               30,4821               30,2468
# 15               59,2212  ...               29,0061               31,8784
# 16               30,0926  ...               40,7465               29,5593
# 17               15,7137  ...               34,6686               37,4654
# 18                26,289  ...               29,8416                33,712
# 19               23,1288  ...               26,5358               45,3411
# 20               28,9745  ...               29,4586               42,3494
# 21               28,8041  ...               37,4428               50,3109
# 22               34,5991  ...               31,0332               51,8057
# 23               35,1264  ...               31,2051               77,8452
# 24               29,3343  ...               35,2698               76,0883
# 25               27,4753  ...               35,4874               71,1423
# 26               26,9586  ...               31,2139               61,1668
# 27               30,5969  ...               33,7941               46,4778
# 28               27,7882  ...               34,8229                47,221
#
#                      116                   117                   118  \
# 0           WpKoniWyszyn          WpPilaKusoci          WpPoznDabrow
# 1                   PM10                  PM10                  PM10
# 2                     1g                    1g                    1g
# 3                  ug/m3                 ug/m3                 ug/m3
# 4   WpKoniWyszyn-PM10-1g  WpPilaKusoci-PM10-1g  WpPoznDabrow-PM10-1g
# 5                  18,53                62,105               33,2655
# 6                20,0714               114,091               46,4343
# 7                  21,63               19,2682               29,8119
# 8                23,7979               13,1749               30,7476
# 9                  25,99               14,5591               31,2552
# 10               23,6829               19,2045               27,3711
# 11                 21,35               27,8473               27,7044
# 12               21,1611               40,0362               28,2723
# 13                 20,97               38,6995               29,0471
# 14               23,2494               32,6638               32,5948
# 15                 25,58               31,1817               40,2358
# 16               22,0447               29,5448               40,5701
# 17                 18,43               34,9204               43,8689
# 18               18,2273               36,8418               42,0267
# 19                 18,02               34,0992               43,4222
# 20               19,0633               32,6594               42,3697
# 21                 20,13               29,4411               45,2469
# 22               27,2104               31,7782               40,9172
# 23                 34,45                28,883                37,625
# 24               32,7936               32,2889                36,995
# 25                  31,1               31,8713               38,5462
# 26               28,8256               31,5281               39,7005
# 27                  26,5               34,2051                39,921
# 28               26,1391               32,9608               44,7804
#
#                      119                   120                   121  \
# 0           WpPoznPolank          ZpKoszArKraj          ZpSzczAndr01
# 1                   PM10                  PM10                  PM10
# 2                     1g                    1g                    1g
# 3                  ug/m3                 ug/m3                 ug/m3
# 4   WpPoznPolank-PM10-1g  ZpKoszArKraj-PM10-1g  ZpSzczAndr01-PM10-1g
# 5                  47,02                24,221               60,0293
# 6                62,9012               24,9919               50,9891
# 7                  65,17               15,8157               34,6693
# 8                  65,17               9,87341               28,0312
# 9                58,6162               13,6186               28,9273
# 10                 57,68               22,2035               24,9687
# 11                 57,68               27,1062               29,6561
# 12               41,7363               32,5441               25,0225
# 13                 41,03               36,2124                26,797
# 14                 36,03               36,2198                  29,8
# 15               29,1437               27,7726               26,3575
# 16                 28,16               26,1346               22,2342
# 17                 31,16               30,1636               17,2536
# 18                 32,92               33,3375                16,551
# 19                  33,6                31,637               16,6375
# 20                  33,6                32,673               21,9153
# 21               38,0013               28,3097               22,4965
# 22                 38,63               24,2157               27,8379
# 23                 38,63               24,9463               24,8203
# 24               38,3587               27,8662               21,1518
# 25                 38,32               29,7043               22,8919
# 26                 38,32               31,4146               23,0687
# 27                  42,8               29,1271               21,6443
# 28                 43,44               22,9234               23,8777
#
#                      122                   123
# 0           ZpSzczecPrze          ZpSzczLacz04
# 1                   PM10                  PM10
# 2                     1g                    1g
# 3                  ug/m3                 ug/m3
# 4   ZpSzczecPrze-PM10-1g  ZpSzczLacz04-PM10-1g
# 5                20,2558               24,1928
# 6                17,4999               83,2406
# 7                8,88873               39,7984
# 8                7,46767               30,2386
# 9                8,14248               28,8418
# 10                 7,194               29,2547
# 11               12,8063               29,7361
# 12               22,4649               26,2283
# 13               29,6154               25,7462
# 14               34,8172               29,4088
# 15               46,3769               34,8027
# 16               42,7893               27,8928
# 17               29,2108               21,9113
# 18               22,2941                26,873
# 19               20,5722               23,9147
# 20               22,1508               14,7739
# 21               21,9033               23,7025
# 22               24,2227               28,7647
# 23               21,0261               26,5144
# 24               17,3711               31,7301
# 25               17,6264               28,6355
# 26               19,7741               22,4971
# 27               27,8107               23,2227
# 28               31,6874               24,7601
#
# [29 rows x 124 columns]

# %%
df.info()   # they are not stored as nunmeric data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8765 entries, 0 to 8764
# Columns: 124 entries, Nr to 123
# dtypes: object(124)
# memory usage: 8.3+ MB

# %%
# I picked a column with no empty values
Dzialoszyn_df = df.iloc[5:,3]

# %%
Dzialoszyn_df[0:10]   # they used "," instead of "."
# Out:
# 5       405,0
# 6     310,984
# 7     455,381
# 8       290,6
# 9     263,553
# 10    170,725
# 11    133,309
# 12    111,125
# 13     179,91
# 14    162,899
# Name: 3, dtype: object

# %%
replaced = Dzialoszyn_df.str.replace(",",".")   # replaced with dot

# %%
replaced[0:10]
# Out:
# 5       405.0
# 6     310.984
# 7     455.381
# 8       290.6
# 9     263.553
# 10    170.725
# 11    133.309
# 12    111.125
# 13     179.91
# 14    162.899
# Name: 3, dtype: object

# %%
numeric = pd.to_numeric(replaced)  # make them all float

# %%
numeric[0:10]
# Out:
# 5     405.000
# 6     310.984
# 7     455.381
# 8     290.600
# 9     263.553
# 10    170.725
# 11    133.309
# 12    111.125
# 13    179.910
# 14    162.899
# Name: 3, dtype: float64

# %%
np.isnan(numeric).any()
# Out:
# True

# %%
plt.figure(figsize=(20,10))
plt.plot(numeric)
plt.show()

# %% [markdown]
# # Select best stations

# %%
count_nans = df.iloc[5:, 2:].isna().sum()
best_stations_index = count_nans.nsmallest(10).index
best_stations = df[best_stations_index].iloc[5:,:]
best_stations.columns = df[best_stations_index].loc[[0]].values[0]
best_stations.head()
# Out:
#   MpTarRoSitko SlTychyTolst ZpKoszArKraj MpNoSaczNadb ZpSzczecPrze  \
# 5      286,547       43,767       24,221      430,315      20,2558
# 6      277,584      36,3929      24,9919      289,301      17,4999
# 7      294,011       38,949      15,8157      251,635      8,88873
# 8      234,649      39,6057      9,87341      235,258      7,46767
# 9      196,482      37,7051      13,6186      189,809      8,14248
#
#   MpKrakAlKras PmGdaKacze02 SlWodzGalczy SlRybniBorki MzPlocMiReja
# 5      213,733         22,1      97,5863      56,9406    49,591231
# 6      213,868         11,9      97,6305      60,6056    39,695604
# 7      221,923          4,8      66,6252      54,7129    39,695604
# 8       244,69          5,1      53,7598      47,2334    39,695604
# 9      224,673          5,1       48,948      42,1408    39,695604

# %% [markdown]
# # Preprocessing

# %%
def preprocessData(data):
    data_dot = data.str.replace(",",".")
    data_numeric = pd.to_numeric(data_dot)

# %%
best_stations_df = pd.DataFrame([pd.to_numeric(best_stations[station].str.replace(",",".")) for station in best_stations])
best_stations_df = best_stations_df.transpose()
best_stations_df.head()
# Out:
#    MpTarRoSitko  SlTychyTolst  ZpKoszArKraj  MpNoSaczNadb  ZpSzczecPrze  \
# 5       286.547       43.7670      24.22100       430.315      20.25580
# 6       277.584       36.3929      24.99190       289.301      17.49990
# 7       294.011       38.9490      15.81570       251.635       8.88873
# 8       234.649       39.6057       9.87341       235.258       7.46767
# 9       196.482       37.7051      13.61860       189.809       8.14248
#
#    MpKrakAlKras  PmGdaKacze02  SlWodzGalczy  SlRybniBorki  MzPlocMiReja
# 5       213.733          22.1       97.5863       56.9406     49.591231
# 6       213.868          11.9       97.6305       60.6056     39.695604
# 7       221.923           4.8       66.6252       54.7129     39.695604
# 8       244.690           5.1       53.7598       47.2334     39.695604
# 9       224.673           5.1       48.9480       42.1408     39.695604

# %% [markdown]
# # Plotting

# %%
for station in best_stations_df:
    best_stations_df[station].plot(figsize=(12,8))

# %%
best_stations_df.isna().sum()
# Out:
# MpTarRoSitko     3
# SlTychyTolst    10
# ZpKoszArKraj    16
# MpNoSaczNadb    18
# ZpSzczecPrze    20
# MpKrakAlKras    21
# PmGdaKacze02    27
# SlWodzGalczy    30
# SlRybniBorki    35
# MzPlocMiReja    38
# dtype: int64

# %% [markdown]
# # Handling missing values
# I take the simplest approach and take mean of two neighbours

# %%
for i in best_stations_df['MpTarRoSitko'][best_stations_df['MpTarRoSitko'].isna()].index:
    if not(np.isnan(best_stations_df['MpTarRoSitko'].loc[i-1]) or np.isnan(best_stations_df['MpTarRoSitko'].loc[i+1])):
        best_stations_df['MpTarRoSitko'].loc[i] = (best_stations_df['MpTarRoSitko'].loc[i-1] + best_stations_df['MpTarRoSitko'].loc[i+1])/2

# %%
sum(best_stations_df['MpTarRoSitko'].isna())
# Out:
# 0

# %% [markdown]
# # Moving average

# %%
best_stations_df['MpTarRoSitko'].rolling(24).mean().plot()

# %%
best_stations_df['MpTarRoSitko'].plot()

# %% [markdown]
# # Average for each day

# %%
best_station_arr = best_stations_df['MpTarRoSitko'].values.reshape(365,24)
f'shape = {daily_df.shape} type = {type(best_station_arr)}'
# Out:
# "shape = (24, 365) type = <class 'numpy.ndarray'>"

# %%
daily_arr = np.mean(best_station_arr, axis=1)
plt.plot(daily_arr)
